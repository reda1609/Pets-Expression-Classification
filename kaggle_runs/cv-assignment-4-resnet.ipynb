# %%
! rm -rf /kaggle/working/Pets-Expression-Classification
! mkdir -p Pets-Expression-Classification
! git clone https://github.com/reda1609/Pets-Expression-Classification.git /kaggle/working/Pets-Expression-Classification
# Out:
# Cloning into '/kaggle/working/Pets-Expression-Classification'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 97 (delta 46), reused 74 (delta 26), pack-reused 0 (from 0)
# Receiving objects: 100% (97/97), 284.95 KiB | 21.92 MiB/s, done.
# Resolving deltas: 100% (46/46), done.

# %%
! chmod +x /kaggle/working/Pets-Expression-Classification/train.py

# %%
! pip install lightning --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 40.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
! python3 /kaggle/working/Pets-Expression-Classification/train.py --model ResNet50 --save_k 1 --max_epochs 30 --batch_size 64 --augment True \
--root_dir "/kaggle/working" \
--data_dir "/kaggle/input/pets-facial-expression-dataset/Master Folder" \
--notebook \
--lr 0.001 --patience 12
# Out:
# Augmentation complete! Check: /kaggle/working/Augmented_Folder/train
# Train folder path: /kaggle/working/Augmented_Folder/train
# Validation folder path: /kaggle/input/pets-facial-expression-dataset/Master Folder/valid
# Dataset loaded: 4 classes found: ['Angry', 'Other', 'Sad', 'happy']
# Loaded ResNet50 model, configured for 4 classes.
# Model name: ResNet50
# Logger save directory: /kaggle/working/logs
# Determined run version for all loggers: 0
# INFO: GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# 2025-05-27 00:40:44.168064: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
! python3 /kaggle/working/Pets-Expression-Classification/train.py --model VGG16 --save_k 1 --max_epochs 30 --batch_size 64 --augment False \
--root_dir "/kaggle/working" \
--data_dir "/kaggle/input/pets-facial-expression-dataset/Master Folder" \
--notebook \
--lr 0.001 --patience 12
# Out:
# Augmentation complete! Check: /kaggle/working/Augmented_Folder/train
# Train folder path: /kaggle/working/Augmented_Folder/train
# Validation folder path: /kaggle/input/pets-facial-expression-dataset/Master Folder/valid
# Dataset loaded: 4 classes found: ['Angry', 'Other', 'Sad', 'happy']
# Loaded VGG16 model, configured for 4 classes.
# Model name: VGG16
# Logger save directory: /kaggle/working/logs
# Determined run version for all loggers: 0
# INFO: GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# 2025-05-27 00:47:20.857371: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
! rm -rf /kaggle/working/Augmented_Folder
