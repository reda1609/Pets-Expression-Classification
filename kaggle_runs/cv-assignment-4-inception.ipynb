# %%
! rm -rf /kaggle/working/Pets-Expression-Classification
! mkdir -p Pets-Expression-Classification
! git clone https://github.com/reda1609/Pets-Expression-Classification.git /kaggle/working/Pets-Expression-Classification
# Out:
# Cloning into '/kaggle/working/Pets-Expression-Classification'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 97 (delta 46), reused 74 (delta 26), pack-reused 0 (from 0)
# Receiving objects: 100% (97/97), 284.95 KiB | 10.55 MiB/s, done.
# Resolving deltas: 100% (46/46), done.

# %%
! chmod +x /kaggle/working/Pets-Expression-Classification/train.py

# %%
! pip install lightning --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 26.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 51.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.3.2 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# bigframes 1.42.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pandas-gbq 0.28.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.

# %%
! ls /kaggle/working
# Out:
# __notebook__.ipynb  Pets-Expression-Classification

# %%
! python3 /kaggle/working/Pets-Expression-Classification/train.py --model InceptionV3 --save_k 3 --max_epochs 25 --batch_size 64 --augment True \
--root_dir "/kaggle/working" \
--data_dir "/kaggle/input/pets-facial-expression-dataset/Master Folder" \
--notebook \
--lr 0.001 --patience 12
# Out:
# Augmentation complete! Check: /kaggle/working/Augmented_Folder/train
# Train folder path: /kaggle/working/Augmented_Folder/train
# Validation folder path: /kaggle/input/pets-facial-expression-dataset/Master Folder/valid
# Dataset loaded: 4 classes found: ['Angry', 'Other', 'Sad', 'happy']
# Loaded InceptionV3 model, configured for 4 classes.
# Model name: InceptionV3
# Logger save directory: /kaggle/working/logs
# Determined run version for all loggers: 0
# INFO: GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# 2025-05-27 00:40:13.949448: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748306414.140574      67 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748306414.197405      67 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name                 | Type                | Params | Mode
# ---------------------------------------------------------------------
# 0 | model                | InceptionV3         | 23.8 M | train
# 1 | train_accuracy       | MulticlassAccuracy  | 0      | train
# 2 | val_accuracy         | MulticlassAccuracy  | 0      | train
# 3 | val_precision_metric | MulticlassPrecision | 0      | train
# 4 | val_recall_metric    | MulticlassRecall    | 0      | train
# 5 | val_f1_metric        | MulticlassF1Score   | 0      | train
# ---------------------------------------------------------------------
# 23.8 M    Trainable params
# 0         Non-trainable params
# 23.8 M    Total params
# 95.099    Total estimated model params size (MB)
# 404       Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|█| 63/63 [00:37<00:00,  1.70it/s, v_num=0, train_loss_step=1.270,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00,  4.35it/s]
# Epoch 0 Validation Metrics (InceptionV3):
#   Val Loss: 1.3632
#   Val Acc: 0.3889
#   Val Precision: 0.3615
#   Val Recall: 0.3538
#   Val F1-Score: 0.2988
# ------------------------------
#
# Epoch 0: 100%|█| 63/63 [00:37<00:00,  1.67it/s, v_num=0, train_loss_step=1.270,
# Epoch 0 Training Metrics (InceptionV3):
#   Train Loss: 6.9944
#   Train Acc: 0.2830
# ------------------------------
# Epoch 1: 100%|█| 63/63 [00:36<00:00,  1.73it/s, v_num=0, train_loss_step=1.970,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 11.87it/s]
# Epoch 1 Validation Metrics (InceptionV3):
#   Val Loss: 21.4986
#   Val Acc: 0.3611
#   Val Precision: 0.2741
#   Val Recall: 0.3230
#   Val F1-Score: 0.2677
# ------------------------------
#
# Epoch 1: 100%|█| 63/63 [00:36<00:00,  1.71it/s, v_num=0, train_loss_step=1.970,
# Epoch 1 Training Metrics (InceptionV3):
#   Train Loss: 2.3329
#   Train Acc: 0.3313
# ------------------------------
# Epoch 2: 100%|█| 63/63 [00:36<00:00,  1.73it/s, v_num=0, train_loss_step=2.440,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 11.85it/s]
# Epoch 2 Validation Metrics (InceptionV3):
#   Val Loss: 1.9151
#   Val Acc: 0.3333
#   Val Precision: 0.2422
#   Val Recall: 0.2902
#   Val F1-Score: 0.2594
# ------------------------------
#
# Epoch 2: 100%|█| 63/63 [00:36<00:00,  1.70it/s, v_num=0, train_loss_step=2.440,
# Epoch 2 Training Metrics (InceptionV3):
#   Train Loss: 1.9855
#   Train Acc: 0.3873
# ------------------------------
# Epoch 3: 100%|█| 63/63 [00:36<00:00,  1.72it/s, v_num=0, train_loss_step=1.280,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 11.87it/s]
# Epoch 3 Validation Metrics (InceptionV3):
#   Val Loss: 2.5862
#   Val Acc: 0.2778
#   Val Precision: 0.3182
#   Val Recall: 0.2682
#   Val F1-Score: 0.2742
# ------------------------------
#
# Epoch 3: 100%|█| 63/63 [00:37<00:00,  1.70it/s, v_num=0, train_loss_step=1.280,
# Epoch 3 Training Metrics (InceptionV3):
#   Train Loss: 1.8199
#   Train Acc: 0.4367
# ------------------------------
# Epoch 4: 100%|█| 63/63 [00:36<00:00,  1.72it/s, v_num=0, train_loss_step=1.190,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 11.91it/s]
# Epoch 4 Validation Metrics (InceptionV3):
#   Val Loss: 4.8482
#   Val Acc: 0.3889
#   Val Precision: 0.4500
#   Val Recall: 0.3715
#   Val F1-Score: 0.3765
# ------------------------------
#
# Epoch 4: 100%|█| 63/63 [00:37<00:00,  1.70it/s, v_num=0, train_loss_step=1.190,
# Epoch 4 Training Metrics (InceptionV3):
#   Train Loss: 1.7197
#   Train Acc: 0.4485
# ------------------------------
# Epoch 5: 100%|█| 63/63 [00:36<00:00,  1.72it/s, v_num=0, train_loss_step=1.430,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 11.87it/s]
# Epoch 5 Validation Metrics (InceptionV3):
#   Val Loss: 11.1082
#   Val Acc: 0.4167
#   Val Precision: 0.3690
#   Val Recall: 0.3934
#   Val F1-Score: 0.3777
# ------------------------------
#
# Epoch 5: 100%|█| 63/63 [00:37<00:00,  1.70it/s, v_num=0, train_loss_step=1.430,
# Epoch 5 Training Metrics (InceptionV3):
#   Train Loss: 1.2991
#   Train Acc: 0.5250
# ------------------------------
# Epoch 6: 100%|█| 63/63 [00:36<00:00,  1.73it/s, v_num=0, train_loss_step=1.230,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 11.52it/s]
# Epoch 6 Validation Metrics (InceptionV3):
#   Val Loss: 12.3624
#   Val Acc: 0.3333
#   Val Precision: 0.3720
#   Val Recall: 0.3159
#   Val F1-Score: 0.3268
# ------------------------------
#
# Epoch 6: 100%|█| 63/63 [00:36<00:00,  1.70it/s, v_num=0, train_loss_step=1.230,
# Epoch 6 Training Metrics (InceptionV3):
#   Train Loss: 1.2708
#   Train Acc: 0.5882
# ------------------------------
# Epoch 7: 100%|█| 63/63 [00:36<00:00,  1.73it/s, v_num=0, train_loss_step=0.792,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 11.89it/s]
# Epoch 7 Validation Metrics (InceptionV3):
#   Val Loss: 2.8231
#   Val Acc: 0.4444
#   Val Precision: 0.4688
#   Val Recall: 0.4235
#   Val F1-Score: 0.4183
# ------------------------------
#
# Epoch 7: 100%|█| 63/63 [00:36<00:00,  1.70it/s, v_num=0, train_loss_step=0.792,
# Epoch 7 Training Metrics (InceptionV3):
#   Train Loss: 1.1512
#   Train Acc: 0.6140
# ------------------------------
# Epoch 8: 100%|█| 63/63 [00:36<00:00,  1.73it/s, v_num=0, train_loss_step=0.699,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 11.98it/s]
# Epoch 8 Validation Metrics (InceptionV3):
#   Val Loss: 2.2271
#   Val Acc: 0.4167
#   Val Precision: 0.4248
#   Val Recall: 0.4169
#   Val F1-Score: 0.4094
# ------------------------------
#
# Epoch 8: 100%|█| 63/63 [00:36<00:00,  1.71it/s, v_num=0, train_loss_step=0.699,
# Epoch 8 Training Metrics (InceptionV3):
#   Train Loss: 0.9058
#   Train Acc: 0.6845
# ------------------------------
# Epoch 9: 100%|█| 63/63 [00:36<00:00,  1.73it/s, v_num=0, train_loss_step=0.986,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 11.85it/s]
# Epoch 9 Validation Metrics (InceptionV3):
#   Val Loss: 4.6491
#   Val Acc: 0.3889
#   Val Precision: 0.3770
#   Val Recall: 0.3758
#   Val F1-Score: 0.3696
# ------------------------------
#
# Epoch 9: 100%|█| 63/63 [00:36<00:00,  1.70it/s, v_num=0, train_loss_step=0.986,
# Epoch 9 Training Metrics (InceptionV3):
#   Train Loss: 0.7019
#   Train Acc: 0.7460
# ------------------------------
# Epoch 10: 100%|█| 63/63 [00:36<00:00,  1.72it/s, v_num=0, train_loss_step=0.639,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 11.88it/s]
# Epoch 10 Validation Metrics (InceptionV3):
#   Val Loss: 3.7495
#   Val Acc: 0.3889
#   Val Precision: 0.3798
#   Val Recall: 0.3859
#   Val F1-Score: 0.3713
# ------------------------------
#
# Epoch 10: 100%|█| 63/63 [00:37<00:00,  1.70it/s, v_num=0, train_loss_step=0.639,
# Epoch 10 Training Metrics (InceptionV3):
#   Train Loss: 0.6666
#   Train Acc: 0.7617
# ------------------------------
# Epoch 11: 100%|█| 63/63 [00:36<00:00,  1.73it/s, v_num=0, train_loss_step=0.324,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 11.92it/s]
# Epoch 11 Validation Metrics (InceptionV3):
#   Val Loss: 4.9566
#   Val Acc: 0.3611
#   Val Precision: 0.3452
#   Val Recall: 0.3558
#   Val F1-Score: 0.3306
# ------------------------------
#
# Epoch 11: 100%|█| 63/63 [00:36<00:00,  1.71it/s, v_num=0, train_loss_step=0.324,
# Epoch 11 Training Metrics (InceptionV3):
#   Train Loss: 0.5866
#   Train Acc: 0.8077
# ------------------------------
# Epoch 12: 100%|█| 63/63 [00:36<00:00,  1.72it/s, v_num=0, train_loss_step=0.677,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 11.89it/s]
# Epoch 12 Validation Metrics (InceptionV3):
#   Val Loss: 3.1755
#   Val Acc: 0.4167
#   Val Precision: 0.4277
#   Val Recall: 0.4336
#   Val F1-Score: 0.4144
# ------------------------------
#
# Epoch 12: 100%|█| 63/63 [00:37<00:00,  1.70it/s, v_num=0, train_loss_step=0.677,
# Epoch 12 Training Metrics (InceptionV3):
#   Train Loss: 0.4936
#   Train Acc: 0.8440
# ------------------------------
# Epoch 12: 100%|█| 63/63 [00:38<00:00,  1.64it/s, v_num=0, train_loss_step=0.677,
#
# Training Ended for InceptionV3. Generating final reports...
# Saving reports to: /kaggle/working/logs/InceptionV3/version_0/custom_reports_and_plots
# Saved confusion matrix to /kaggle/working/logs/InceptionV3/version_0/custom_reports_and_plots/InceptionV3_v0_confusion_matrix.png
#
# Final Classification Report - InceptionV3 (v0):
#               precision    recall  f1-score   support
#
#        Angry       0.34      0.37      0.36       117
#        Other       0.27      0.26      0.26        78
#          Sad       0.29      0.30      0.30       130
#        happy       0.56      0.52      0.54       143
#
#     accuracy                           0.38       468
#    macro avg       0.37      0.36      0.36       468
# weighted avg       0.38      0.38      0.38       468
#
# Saved classification report to /kaggle/working/logs/InceptionV3/version_0/custom_reports_and_plots/InceptionV3_v0_classification_report.txt
# Saved metrics plot to /kaggle/working/logs/InceptionV3/version_0/custom_reports_and_plots/InceptionV3_v0_metrics_over_epochs.png

# %%
! python3 /kaggle/working/Pets-Expression-Classification/train.py --model DenseNet121 --save_k 3 --max_epochs 25 --batch_size 64 --augment False \
--root_dir "/kaggle/working" \
--data_dir "/kaggle/input/pets-facial-expression-dataset/Master Folder" \
--notebook \
--lr 0.001 --patience 12
# Out:
# Augmentation complete! Check: /kaggle/working/Augmented_Folder/train
# Train folder path: /kaggle/working/Augmented_Folder/train
# Validation folder path: /kaggle/input/pets-facial-expression-dataset/Master Folder/valid
# Dataset loaded: 4 classes found: ['Angry', 'Other', 'Sad', 'happy']
# Loaded DenseNet121 model, configured for 4 classes.
# Model name: DenseNet121
# Logger save directory: /kaggle/working/logs
# Determined run version for all loggers: 0
# INFO: GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# 2025-05-27 00:49:15.212260: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748306955.235809     422 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748306955.242975     422 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name                 | Type                | Params | Mode
# ---------------------------------------------------------------------
# 0 | model                | DenseNet121         | 7.0 M  | train
# 1 | train_accuracy       | MulticlassAccuracy  | 0      | train
# 2 | val_accuracy         | MulticlassAccuracy  | 0      | train
# 3 | val_precision_metric | MulticlassPrecision | 0      | train
# 4 | val_recall_metric    | MulticlassRecall    | 0      | train
# 5 | val_f1_metric        | MulticlassF1Score   | 0      | train
# ---------------------------------------------------------------------
# 7.0 M     Trainable params
# 0         Non-trainable params
# 7.0 M     Total params
# 27.832    Total estimated model params size (MB)
# 442       Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|█| 63/63 [00:22<00:00,  2.79it/s, v_num=0, train_loss_step=1.290,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00,  4.80it/s]
# Epoch 0 Validation Metrics (DenseNet121):
#   Val Loss: 1.5777
#   Val Acc: 0.3056
#   Val Precision: 0.2489
#   Val Recall: 0.2992
#   Val F1-Score: 0.2516
# ------------------------------
#
# Epoch 0: 100%|█| 63/63 [00:23<00:00,  2.73it/s, v_num=0, train_loss_step=1.290,
# Epoch 0 Training Metrics (DenseNet121):
#   Train Loss: 1.3890
#   Train Acc: 0.2985
# ------------------------------
# Epoch 1: 100%|█| 63/63 [00:22<00:00,  2.83it/s, v_num=0, train_loss_step=1.350,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 15.45it/s]
# Epoch 1 Validation Metrics (DenseNet121):
#   Val Loss: 1.4555
#   Val Acc: 0.3056
#   Val Precision: 0.1583
#   Val Recall: 0.2917
#   Val F1-Score: 0.2034
# ------------------------------
#
# Epoch 1: 100%|█| 63/63 [00:22<00:00,  2.78it/s, v_num=0, train_loss_step=1.350,
# Epoch 1 Training Metrics (DenseNet121):
#   Train Loss: 1.3548
#   Train Acc: 0.3340
# ------------------------------
# Epoch 2: 100%|█| 63/63 [00:22<00:00,  2.83it/s, v_num=0, train_loss_step=1.370,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 15.51it/s]
# Epoch 2 Validation Metrics (DenseNet121):
#   Val Loss: 2.4833
#   Val Acc: 0.2222
#   Val Precision: 0.1850
#   Val Recall: 0.2311
#   Val F1-Score: 0.1656
# ------------------------------
#
# Epoch 2: 100%|█| 63/63 [00:22<00:00,  2.78it/s, v_num=0, train_loss_step=1.370,
# Epoch 2 Training Metrics (DenseNet121):
#   Train Loss: 1.3334
#   Train Acc: 0.3562
# ------------------------------
# Epoch 3: 100%|█| 63/63 [00:22<00:00,  2.83it/s, v_num=0, train_loss_step=1.210,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 15.47it/s]
# Epoch 3 Validation Metrics (DenseNet121):
#   Val Loss: 1.3838
#   Val Acc: 0.3056
#   Val Precision: 0.4761
#   Val Recall: 0.3043
#   Val F1-Score: 0.2847
# ------------------------------
#
# Epoch 3: 100%|█| 63/63 [00:22<00:00,  2.78it/s, v_num=0, train_loss_step=1.210,
# Epoch 3 Training Metrics (DenseNet121):
#   Train Loss: 1.3264
#   Train Acc: 0.3640
# ------------------------------
# Epoch 4: 100%|█| 63/63 [00:22<00:00,  2.83it/s, v_num=0, train_loss_step=1.210,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 15.42it/s]
# Epoch 4 Validation Metrics (DenseNet121):
#   Val Loss: 1.7957
#   Val Acc: 0.3333
#   Val Precision: 0.3125
#   Val Recall: 0.2975
#   Val F1-Score: 0.2819
# ------------------------------
#
# Epoch 4: 100%|█| 63/63 [00:22<00:00,  2.78it/s, v_num=0, train_loss_step=1.210,
# Epoch 4 Training Metrics (DenseNet121):
#   Train Loss: 1.2917
#   Train Acc: 0.3940
# ------------------------------
# Epoch 5: 100%|█| 63/63 [00:22<00:00,  2.84it/s, v_num=0, train_loss_step=1.290,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 15.44it/s]
# Epoch 5 Validation Metrics (DenseNet121):
#   Val Loss: 1.4702
#   Val Acc: 0.3889
#   Val Precision: 0.4750
#   Val Recall: 0.4025
#   Val F1-Score: 0.3731
# ------------------------------
#
# Epoch 5: 100%|█| 63/63 [00:22<00:00,  2.79it/s, v_num=0, train_loss_step=1.290,
# Epoch 5 Training Metrics (DenseNet121):
#   Train Loss: 1.2628
#   Train Acc: 0.4047
# ------------------------------
# Epoch 6: 100%|█| 63/63 [00:22<00:00,  2.83it/s, v_num=0, train_loss_step=1.510,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 15.47it/s]
# Epoch 6 Validation Metrics (DenseNet121):
#   Val Loss: 2.8252
#   Val Acc: 0.3611
#   Val Precision: 0.1802
#   Val Recall: 0.3068
#   Val F1-Score: 0.2254
# ------------------------------
#
# Epoch 6: 100%|█| 63/63 [00:22<00:00,  2.79it/s, v_num=0, train_loss_step=1.510,
# Epoch 6 Training Metrics (DenseNet121):
#   Train Loss: 1.2563
#   Train Acc: 0.4157
# ------------------------------
# Epoch 7: 100%|█| 63/63 [00:22<00:00,  2.83it/s, v_num=0, train_loss_step=1.230,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 15.51it/s]
# Epoch 7 Validation Metrics (DenseNet121):
#   Val Loss: 1.8543
#   Val Acc: 0.4167
#   Val Precision: 0.4556
#   Val Recall: 0.3551
#   Val F1-Score: 0.3024
# ------------------------------
#
# Epoch 7: 100%|█| 63/63 [00:22<00:00,  2.79it/s, v_num=0, train_loss_step=1.230,
# Epoch 7 Training Metrics (DenseNet121):
#   Train Loss: 1.2173
#   Train Acc: 0.4485
# ------------------------------
# Epoch 8: 100%|█| 63/63 [00:22<00:00,  2.83it/s, v_num=0, train_loss_step=1.130,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 15.50it/s]
# Epoch 8 Validation Metrics (DenseNet121):
#   Val Loss: 1.4178
#   Val Acc: 0.2778
#   Val Precision: 0.3417
#   Val Recall: 0.3343
#   Val F1-Score: 0.2597
# ------------------------------
#
# Epoch 8: 100%|█| 63/63 [00:22<00:00,  2.78it/s, v_num=0, train_loss_step=1.130,
# Epoch 8 Training Metrics (DenseNet121):
#   Train Loss: 1.1845
#   Train Acc: 0.4557
# ------------------------------
# Epoch 9: 100%|█| 63/63 [00:22<00:00,  2.82it/s, v_num=0, train_loss_step=1.260,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 15.49it/s]
# Epoch 9 Validation Metrics (DenseNet121):
#   Val Loss: 1.7760
#   Val Acc: 0.2222
#   Val Precision: 0.2051
#   Val Recall: 0.1965
#   Val F1-Score: 0.1981
# ------------------------------
#
# Epoch 9: 100%|█| 63/63 [00:22<00:00,  2.77it/s, v_num=0, train_loss_step=1.260,
# Epoch 9 Training Metrics (DenseNet121):
#   Train Loss: 1.1807
#   Train Acc: 0.4685
# ------------------------------
# Epoch 10: 100%|█| 63/63 [00:22<00:00,  2.84it/s, v_num=0, train_loss_step=1.110,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 15.45it/s]
# Epoch 10 Validation Metrics (DenseNet121):
#   Val Loss: 1.4668
#   Val Acc: 0.3333
#   Val Precision: 0.3229
#   Val Recall: 0.3331
#   Val F1-Score: 0.3246
# ------------------------------
#
# Epoch 10: 100%|█| 63/63 [00:22<00:00,  2.79it/s, v_num=0, train_loss_step=1.110,
# Epoch 10 Training Metrics (DenseNet121):
#   Train Loss: 1.1457
#   Train Acc: 0.4782
# ------------------------------
# Epoch 11: 100%|█| 63/63 [00:22<00:00,  2.83it/s, v_num=0, train_loss_step=1.060,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 14.89it/s]
# Epoch 11 Validation Metrics (DenseNet121):
#   Val Loss: 1.6047
#   Val Acc: 0.3611
#   Val Precision: 0.3607
#   Val Recall: 0.3937
#   Val F1-Score: 0.3530
# ------------------------------
#
# Epoch 11: 100%|█| 63/63 [00:22<00:00,  2.78it/s, v_num=0, train_loss_step=1.060,
# Epoch 11 Training Metrics (DenseNet121):
#   Train Loss: 1.1049
#   Train Acc: 0.4967
# ------------------------------
# Epoch 12: 100%|█| 63/63 [00:22<00:00,  2.84it/s, v_num=0, train_loss_step=1.160,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 15.50it/s]
# Epoch 12 Validation Metrics (DenseNet121):
#   Val Loss: 2.0923
#   Val Acc: 0.2778
#   Val Precision: 0.3438
#   Val Recall: 0.2682
#   Val F1-Score: 0.2753
# ------------------------------
#
# Epoch 12: 100%|█| 63/63 [00:22<00:00,  2.79it/s, v_num=0, train_loss_step=1.160,
# Epoch 12 Training Metrics (DenseNet121):
#   Train Loss: 1.0775
#   Train Acc: 0.5238
# ------------------------------
# Epoch 13: 100%|█| 63/63 [00:22<00:00,  2.83it/s, v_num=0, train_loss_step=1.180,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 15.46it/s]
# Epoch 13 Validation Metrics (DenseNet121):
#   Val Loss: 2.8790
#   Val Acc: 0.2500
#   Val Precision: 0.2584
#   Val Recall: 0.2636
#   Val F1-Score: 0.2069
# ------------------------------
#
# Epoch 13: 100%|█| 63/63 [00:22<00:00,  2.78it/s, v_num=0, train_loss_step=1.180,
# Epoch 13 Training Metrics (DenseNet121):
#   Train Loss: 1.0561
#   Train Acc: 0.5408
# ------------------------------
# Epoch 14: 100%|█| 63/63 [00:22<00:00,  2.82it/s, v_num=0, train_loss_step=0.957,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 15.47it/s]
# Epoch 14 Validation Metrics (DenseNet121):
#   Val Loss: 2.5313
#   Val Acc: 0.2778
#   Val Precision: 0.3494
#   Val Recall: 0.2871
#   Val F1-Score: 0.2795
# ------------------------------
#
# Epoch 14: 100%|█| 63/63 [00:22<00:00,  2.78it/s, v_num=0, train_loss_step=0.957,
# Epoch 14 Training Metrics (DenseNet121):
#   Train Loss: 1.0019
#   Train Acc: 0.5690
# ------------------------------
# Epoch 15: 100%|█| 63/63 [00:22<00:00,  2.82it/s, v_num=0, train_loss_step=1.160,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 15.48it/s]
# Epoch 15 Validation Metrics (DenseNet121):
#   Val Loss: 1.9831
#   Val Acc: 0.2778
#   Val Precision: 0.4185
#   Val Recall: 0.3182
#   Val F1-Score: 0.2822
# ------------------------------
#
# Epoch 15: 100%|█| 63/63 [00:22<00:00,  2.77it/s, v_num=0, train_loss_step=1.160,
# Epoch 15 Training Metrics (DenseNet121):
#   Train Loss: 0.9573
#   Train Acc: 0.5980
# ------------------------------
# Epoch 15: 100%|█| 63/63 [00:23<00:00,  2.70it/s, v_num=0, train_loss_step=1.160,
#
# Training Ended for DenseNet121. Generating final reports...
# Saving reports to: /kaggle/working/logs/DenseNet121/version_0/custom_reports_and_plots
# Saved confusion matrix to /kaggle/working/logs/DenseNet121/version_0/custom_reports_and_plots/DenseNet121_v0_confusion_matrix.png
#
# Final Classification Report - DenseNet121 (v0):
#               precision    recall  f1-score   support
#
#        Angry       0.29      0.35      0.32       144
#        Other       0.19      0.29      0.23        96
#          Sad       0.27      0.21      0.24       160
#        happy       0.49      0.37      0.42       176
#
#     accuracy                           0.31       576
#    macro avg       0.31      0.31      0.30       576
# weighted avg       0.33      0.31      0.31       576
#
# Saved classification report to /kaggle/working/logs/DenseNet121/version_0/custom_reports_and_plots/DenseNet121_v0_classification_report.txt
# Saved metrics plot to /kaggle/working/logs/DenseNet121/version_0/custom_reports_and_plots/DenseNet121_v0_metrics_over_epochs.png

# %%
! python3 /kaggle/working/Pets-Expression-Classification/train.py --model MobileNetV1 --save_k 3 --max_epochs 25 --batch_size 64 --augment False \
--root_dir "/kaggle/working" \
--data_dir "/kaggle/input/pets-facial-expression-dataset/Master Folder" \
--notebook \
--lr 0.001 --patience 12
# Out:
# Augmentation complete! Check: /kaggle/working/Augmented_Folder/train
# Train folder path: /kaggle/working/Augmented_Folder/train
# Validation folder path: /kaggle/input/pets-facial-expression-dataset/Master Folder/valid
# Dataset loaded: 4 classes found: ['Angry', 'Other', 'Sad', 'happy']
# Loaded MobileNetV1 model, configured for 4 classes.
# Model name: MobileNetV1
# Logger save directory: /kaggle/working/logs
# Determined run version for all loggers: 0
# INFO: GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# 2025-05-27 00:55:52.727084: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748307352.750586     854 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748307352.757546     854 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name                 | Type                | Params | Mode
# ---------------------------------------------------------------------
# 0 | model                | MobileNetV1         | 3.2 M  | train
# 1 | train_accuracy       | MulticlassAccuracy  | 0      | train
# 2 | val_accuracy         | MulticlassAccuracy  | 0      | train
# 3 | val_precision_metric | MulticlassPrecision | 0      | train
# 4 | val_recall_metric    | MulticlassRecall    | 0      | train
# 5 | val_f1_metric        | MulticlassF1Score   | 0      | train
# ---------------------------------------------------------------------
# 3.2 M     Trainable params
# 0         Non-trainable params
# 3.2 M     Total params
# 12.844    Total estimated model params size (MB)
# 90        Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|█| 63/63 [00:09<00:00,  6.56it/s, v_num=0, train_loss_step=1.420,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00,  7.09it/s]
# Epoch 0 Validation Metrics (MobileNetV1):
#   Val Loss: 1.6833
#   Val Acc: 0.2500
#   Val Precision: 0.2062
#   Val Recall: 0.2611
#   Val F1-Score: 0.1806
# ------------------------------
#
# Epoch 0: 100%|█| 63/63 [00:10<00:00,  6.28it/s, v_num=0, train_loss_step=1.420,
# Epoch 0 Training Metrics (MobileNetV1):
#   Train Loss: 1.4073
#   Train Acc: 0.3065
# ------------------------------
# Epoch 1: 100%|█| 63/63 [00:09<00:00,  6.69it/s, v_num=0, train_loss_step=1.320,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 42.57it/s]
# Epoch 1 Validation Metrics (MobileNetV1):
#   Val Loss: 1.7435
#   Val Acc: 0.2778
#   Val Precision: 0.1500
#   Val Recall: 0.3333
#   Val F1-Score: 0.2063
# ------------------------------
#
# Epoch 1: 100%|█| 63/63 [00:09<00:00,  6.47it/s, v_num=0, train_loss_step=1.320,
# Epoch 1 Training Metrics (MobileNetV1):
#   Train Loss: 1.3317
#   Train Acc: 0.3735
# ------------------------------
# Epoch 2: 100%|█| 63/63 [00:09<00:00,  6.71it/s, v_num=0, train_loss_step=1.260,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 42.97it/s]
# Epoch 2 Validation Metrics (MobileNetV1):
#   Val Loss: 1.7358
#   Val Acc: 0.3333
#   Val Precision: 0.3304
#   Val Recall: 0.3381
#   Val F1-Score: 0.3180
# ------------------------------
#
# Epoch 2: 100%|█| 63/63 [00:09<00:00,  6.48it/s, v_num=0, train_loss_step=1.260,
# Epoch 2 Training Metrics (MobileNetV1):
#   Train Loss: 1.2517
#   Train Acc: 0.4355
# ------------------------------
# Epoch 3: 100%|█| 63/63 [00:09<00:00,  6.67it/s, v_num=0, train_loss_step=1.080,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 42.52it/s]
# Epoch 3 Validation Metrics (MobileNetV1):
#   Val Loss: 1.8104
#   Val Acc: 0.3056
#   Val Precision: 0.3125
#   Val Recall: 0.3104
#   Val F1-Score: 0.2924
# ------------------------------
#
# Epoch 3: 100%|█| 63/63 [00:09<00:00,  6.42it/s, v_num=0, train_loss_step=1.080,
# Epoch 3 Training Metrics (MobileNetV1):
#   Train Loss: 1.1424
#   Train Acc: 0.5063
# ------------------------------
# Epoch 4: 100%|█| 63/63 [00:09<00:00,  6.73it/s, v_num=0, train_loss_step=1.160,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 43.13it/s]
# Epoch 4 Validation Metrics (MobileNetV1):
#   Val Loss: 1.9906
#   Val Acc: 0.1944
#   Val Precision: 0.1741
#   Val Recall: 0.2333
#   Val F1-Score: 0.1771
# ------------------------------
#
# Epoch 4: 100%|█| 63/63 [00:09<00:00,  6.50it/s, v_num=0, train_loss_step=1.160,
# Epoch 4 Training Metrics (MobileNetV1):
#   Train Loss: 1.0416
#   Train Acc: 0.5688
# ------------------------------
# Epoch 5: 100%|█| 63/63 [00:09<00:00,  6.75it/s, v_num=0, train_loss_step=1.200,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 42.74it/s]
# Epoch 5 Validation Metrics (MobileNetV1):
#   Val Loss: 2.2655
#   Val Acc: 0.3889
#   Val Precision: 0.3860
#   Val Recall: 0.4164
#   Val F1-Score: 0.3871
# ------------------------------
#
# Epoch 5: 100%|█| 63/63 [00:09<00:00,  6.52it/s, v_num=0, train_loss_step=1.200,
# Epoch 5 Training Metrics (MobileNetV1):
#   Train Loss: 0.9492
#   Train Acc: 0.6093
# ------------------------------
# Epoch 6: 100%|█| 63/63 [00:09<00:00,  6.76it/s, v_num=0, train_loss_step=0.787,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 43.40it/s]
# Epoch 6 Validation Metrics (MobileNetV1):
#   Val Loss: 2.1165
#   Val Acc: 0.2778
#   Val Precision: 0.3252
#   Val Recall: 0.3088
#   Val F1-Score: 0.2730
# ------------------------------
#
# Epoch 6: 100%|█| 63/63 [00:09<00:00,  6.53it/s, v_num=0, train_loss_step=0.787,
# Epoch 6 Training Metrics (MobileNetV1):
#   Train Loss: 0.7530
#   Train Acc: 0.7080
# ------------------------------
# Epoch 7: 100%|█| 63/63 [00:09<00:00,  6.66it/s, v_num=0, train_loss_step=0.460,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 42.85it/s]
# Epoch 7 Validation Metrics (MobileNetV1):
#   Val Loss: 2.5687
#   Val Acc: 0.3889
#   Val Precision: 0.3125
#   Val Recall: 0.3725
#   Val F1-Score: 0.3167
# ------------------------------
#
# Epoch 7: 100%|█| 63/63 [00:09<00:00,  6.44it/s, v_num=0, train_loss_step=0.460,
# Epoch 7 Training Metrics (MobileNetV1):
#   Train Loss: 0.5835
#   Train Acc: 0.7755
# ------------------------------
# Epoch 8: 100%|█| 63/63 [00:09<00:00,  6.72it/s, v_num=0, train_loss_step=0.595,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 42.21it/s]
# Epoch 8 Validation Metrics (MobileNetV1):
#   Val Loss: 2.1916
#   Val Acc: 0.4167
#   Val Precision: 0.4318
#   Val Recall: 0.4169
#   Val F1-Score: 0.4119
# ------------------------------
#
# Epoch 8: 100%|█| 63/63 [00:09<00:00,  6.48it/s, v_num=0, train_loss_step=0.595,
# Epoch 8 Training Metrics (MobileNetV1):
#   Train Loss: 0.3629
#   Train Acc: 0.8742
# ------------------------------
# Epoch 9: 100%|█| 63/63 [00:09<00:00,  6.77it/s, v_num=0, train_loss_step=0.417,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 42.74it/s]
# Epoch 9 Validation Metrics (MobileNetV1):
#   Val Loss: 3.5132
#   Val Acc: 0.3611
#   Val Precision: 0.3839
#   Val Recall: 0.3525
#   Val F1-Score: 0.3523
# ------------------------------
#
# Epoch 9: 100%|█| 63/63 [00:09<00:00,  6.53it/s, v_num=0, train_loss_step=0.417,
# Epoch 9 Training Metrics (MobileNetV1):
#   Train Loss: 0.3761
#   Train Acc: 0.8602
# ------------------------------
# Epoch 10: 100%|█| 63/63 [00:09<00:00,  6.72it/s, v_num=0, train_loss_step=0.291,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 42.69it/s]
# Epoch 10 Validation Metrics (MobileNetV1):
#   Val Loss: 2.9337
#   Val Acc: 0.4444
#   Val Precision: 0.4395
#   Val Recall: 0.4359
#   Val F1-Score: 0.4321
# ------------------------------
#
# Epoch 10: 100%|█| 63/63 [00:09<00:00,  6.50it/s, v_num=0, train_loss_step=0.291,
# Epoch 10 Training Metrics (MobileNetV1):
#   Train Loss: 0.2254
#   Train Acc: 0.9197
# ------------------------------
# Epoch 11: 100%|█| 63/63 [00:09<00:00,  6.77it/s, v_num=0, train_loss_step=0.262,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 42.45it/s]
# Epoch 11 Validation Metrics (MobileNetV1):
#   Val Loss: 3.3192
#   Val Acc: 0.3611
#   Val Precision: 0.2692
#   Val Recall: 0.3124
#   Val F1-Score: 0.2810
# ------------------------------
#
# Epoch 11: 100%|█| 63/63 [00:09<00:00,  6.53it/s, v_num=0, train_loss_step=0.262,
# Epoch 11 Training Metrics (MobileNetV1):
#   Train Loss: 0.1654
#   Train Acc: 0.9427
# ------------------------------
# Epoch 12: 100%|█| 63/63 [00:09<00:00,  6.72it/s, v_num=0, train_loss_step=0.457,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00, 42.41it/s]
# Epoch 12 Validation Metrics (MobileNetV1):
#   Val Loss: 4.1291
#   Val Acc: 0.2778
#   Val Precision: 0.2825
#   Val Recall: 0.2798
#   Val F1-Score: 0.2796
# ------------------------------
#
# Epoch 12: 100%|█| 63/63 [00:09<00:00,  6.47it/s, v_num=0, train_loss_step=0.457,
# Epoch 12 Training Metrics (MobileNetV1):
#   Train Loss: 0.1529
#   Train Acc: 0.9448
# ------------------------------
# Epoch 12: 100%|█| 63/63 [00:09<00:00,  6.33it/s, v_num=0, train_loss_step=0.457,
#
# Training Ended for MobileNetV1. Generating final reports...
# Saving reports to: /kaggle/working/logs/MobileNetV1/version_0/custom_reports_and_plots
# Saved confusion matrix to /kaggle/working/logs/MobileNetV1/version_0/custom_reports_and_plots/MobileNetV1_v0_confusion_matrix.png
#
# Final Classification Report - MobileNetV1 (v0):
#               precision    recall  f1-score   support
#
#        Angry       0.31      0.45      0.37       117
#        Other       0.27      0.37      0.31        78
#          Sad       0.24      0.18      0.21       130
#        happy       0.53      0.34      0.41       143
#
#     accuracy                           0.33       468
#    macro avg       0.34      0.34      0.33       468
# weighted avg       0.35      0.33      0.33       468
#
# Saved classification report to /kaggle/working/logs/MobileNetV1/version_0/custom_reports_and_plots/MobileNetV1_v0_classification_report.txt
# Saved metrics plot to /kaggle/working/logs/MobileNetV1/version_0/custom_reports_and_plots/MobileNetV1_v0_metrics_over_epochs.png

# %%
! rm -rf /kaggle/working/Augmented_Folder
